# %% [markdown]
# # Exploratory Data Analysis (EDA)
# This notebook focuses on analyzing the cleaned Olist dataset to uncover trends in revenue, product performance, and customer behavior.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Set visual style
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## 1. Load Cleaned Data
# We will load the data prepared by `src/data_prep.py` or `01_data_cleaning.ipynb`.

# %%
BASE_DIR = os.path.dirname(os.getcwd())
DATA_PATH = os.path.join(BASE_DIR, 'data', 'processed', 'ecommerce_cleaned.csv')

# df = pd.read_csv(DATA_PATH)
# df.head()

# %% [markdown]
# ## 2. Analysis Ideas
# - **Revenue over time:** Plot total payment_value per month.
# - **Top Categories:** Bar chart of top 10 product categories by order count.
# - **Geographic Distribution:** Map or bar chart of sales by customer state.
# - **Order Status:** Pie chart of current order statuses.
